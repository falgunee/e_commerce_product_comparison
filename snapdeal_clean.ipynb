# %%
import pandas as pd
fd=pd.read_excel("Snapdealfile.xlsx")
fd
# Out:
# C:\Users\ABCD\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")
#                                                  Names       Price Discount  \
# 0           Vivo Y81 (32GB, 3GB RAM)- FullView Display  Rs. 10,990  21% Off
# 1                                   Lenovo A7000 (8GB)   Rs. 4,999  38% Off
# 2    OPPO A3s (16GB, 2GB RAM) - 19:9 Full Screen Di...   Rs. 8,990  25% Off
# 3    Lenovo K8 Note (32GB, 3GB RAM) - with Dual Rea...   Rs. 7,749  23% Off
# 4           Vivo Y81 (32GB, 3GB RAM)- FullView Display  Rs. 10,990  21% Off
# 5                     Redmi Note 6 Pro (64GB, 4GB RAM)  Rs. 13,999  13% Off
# 6    OPPO A3S (32GB, 3GB RAM) - 19:9 Full Screen Di...  Rs. 10,990  21% Off
# ...

# %%
fd['Price'] = (fd['Price'].str[3:].astype(str))
fd.head(4)
# Out:
#                                                Names    Price Discount  \
# 0         Vivo Y81 (32GB, 3GB RAM)- FullView Display   10,990  21% Off
# 1                                 Lenovo A7000 (8GB)    4,999  38% Off
# 2  OPPO A3s (16GB, 2GB RAM) - 19:9 Full Screen Di...    8,990  25% Off
# 3  Lenovo K8 Note (32GB, 3GB RAM) - with Dual Rea...    7,749  23% Off
#
#                                                Links
# 0  https://www.snapdeal.com/product/vivo-black-y8...
# 1  https://www.snapdeal.com/product/lenovo-a7000-...
# 2  https://www.snapdeal.com/product/oppo-red-oppo...
# 3  https://www.snapdeal.com/product/lenovo-black-...

# %%
s=fd['Names']
type(s)
a=pd.DataFrame(s.apply(lambda st: st[st.find("(")+1:st.find(")")]))
a.head(4)
# Out:
#            Names
# 0  32GB, 3GB RAM
# 1            8GB
# 2  16GB, 2GB RAM
# 3  32GB, 3GB RAM

# %%
a['STORAGE'] = a.Names.str.split(',').str[0].astype(str)
a['RAM'] = a.Names.str.split(',').str[1].astype(str)
a.head(4)
# Out:
#            Names   ROM   Storage STORAGE       RAM
# 0  32GB, 3GB RAM  32GB   3GB RAM    32GB   3GB RAM
# 1            8GB   8GB       nan     8GB       nan
# 2  16GB, 2GB RAM  16GB   2GB RAM    16GB   2GB RAM
# 3  32GB, 3GB RAM  32GB   3GB RAM    32GB   3GB RAM

# %%
fd["Names"]= fd["Names"].str.split("(",expand=True)
fd.head(4)
fd['Brand_Name'] = fd.Names.str.split(' ', 1).str[0].astype(str)
fd['Model_Name']=fd.Names.str.split(' ', 1).str[1].astype(str)
fd.head(4)
# Out:
#              Names    Price Discount  \
# 0        Vivo Y81    10,990  21% Off
# 1    Lenovo A7000     4,999  38% Off
# 2        OPPO A3s     8,990  25% Off
# 3  Lenovo K8 Note     7,749  23% Off
#
#                                                Links Brand_Name Model_Name
# 0  https://www.snapdeal.com/product/vivo-black-y8...       Vivo       Y81
# 1  https://www.snapdeal.com/product/lenovo-a7000-...     Lenovo     A7000
# 2  https://www.snapdeal.com/product/oppo-red-oppo...       OPPO       A3s
# 3  https://www.snapdeal.com/product/lenovo-black-...     Lenovo   K8 Note

# %%
main_df=pd.concat([fd["Names"],fd["Brand_Name"],fd["Model_Name"],a["RAM"],a["STORAGE"],fd["Price"],fd["Discount"],fd["Links"]],axis=1)

main_df.head(20)
# Out:
#                               Names Brand_Name                 Model_Name  \
# 0                         Vivo Y81        Vivo                       Y81
# 1                     Lenovo A7000      Lenovo                     A7000
# 2                         OPPO A3s        OPPO                       A3s
# 3                   Lenovo K8 Note      Lenovo                   K8 Note
# 4                         Vivo Y81        Vivo                       Y81
# 5                 Redmi Note 6 Pro       Redmi                Note 6 Pro
# 6                         OPPO A3S        OPPO                       A3S
# 7                   Lenovo K8 Note      Lenovo                   K8 Note
# 8                     Vivo Y83 Pro        Vivo                   Y83 Pro
# 9   Apple Space Grey Iphone 5S 16GB      Apple  Space Grey Iphone 5S 16GB
# 10                Redmi Note 5 Pro       Redmi                Note 5 Pro
# 11                        OPPO A83        OPPO                       A83
# ...

# %%
writer = pd.ExcelWriter(r'Main_clean_snapdeal_finaL.xlsx', engine='xlsxwriter',options={'strings_to_urls': False})
main_df.to_excel(writer)
writer.close()
